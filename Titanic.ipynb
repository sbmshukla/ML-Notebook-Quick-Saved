# %% [markdown]
# <a href="https://colab.research.google.com/github/sbmshukla/ML-Notebook-Quick-Saved/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Titanic/train.csv')
df_test  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Dataset/Titanic/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.drop(['PassengerId', "Name"],axis=1,inplace=True)
df_test.drop([ "Name"],axis=1,inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
df_train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_train.drop(['Cabin'],axis=1,inplace=True)
df_test.drop(['Cabin'],axis=1,inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_train.groupby(by=['Sex'])['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df_train.groupby(by=['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df_train['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df_train['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
sns.countplot(x='Sex',hue='Survived',data=df_train)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.histplot(data=df_train,x='Age',hue='Survived',bins='auto')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x='Age', data=df_train)
# Out:
# <Axes: xlabel='Age'>

# %%
## We Will FillOut Age Null Value With Median

# %%
## We Will Fill Out Fare With Mean

# %%
sns.heatmap(df_train.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df_train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_train['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
ticket_counts = df_train['Ticket'].value_counts()
df_train['Has_Duplicate_Ticket'] = df_train['Ticket'].apply(lambda x: ticket_counts[x] > 1)
print(df_train.groupby('Has_Duplicate_Ticket')['Survived'].mean())
# Out:
# Has_Duplicate_Ticket
# False    0.297989
# True     0.520349
# Name: Survived, dtype: float64

# %%
ticket_counts = df_test['Ticket'].value_counts()
df_test['Has_Duplicate_Ticket'] = df_test['Ticket'].apply(lambda x: ticket_counts[x] > 1)

# %%
df_train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Embarked  Has_Duplicate_Ticket
# 0        S                 False
# 1        C                 False
# 2        S                 False
# 3        S                  True
# 4        S                 False

# %%
df_train.drop(['Ticket'],axis=1,inplace=True)
df_test.drop(['Ticket'],axis=1,inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S
#
#    Has_Duplicate_Ticket
# 0                 False
# 1                 False
# 2                 False
# 3                  True
# 4                 False

# %%
df.groupby(by=['Parch'])['Survived'].mean()
# Out:
# Parch
# 0    0.343658
# 1    0.550847
# 2    0.500000
# 3    0.600000
# 4    0.000000
# 5    0.200000
# 6    0.000000
# Name: Survived, dtype: float64

# %%
df_train[df_train['Parch']==4].value_counts()
# Out:
# Survived  Pclass  Sex     Age   SibSp  Parch  Fare     Embarked  Has_Duplicate_Ticket
# 0         1       male    64.0  1      4      263.000  S         True                    1
#           3       female  29.0  0      4      21.075   S         True                    1
#                           45.0  1      4      27.900   S         True                    1
#                   male    40.0  1      4      27.900   S         True                    1
# Name: count, dtype: int64

# %%
df_train.groupby(by=['Embarked'])['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %%
df_train.groupby(by=['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df_train["FamilySize"] = df_train["SibSp"] + df_train["Parch"] + 1
df_test["FamilySize"] = df_test["SibSp"] + df_test["Parch"] + 1

# %%
df_train.groupby(by=['FamilySize'])['Survived'].mean()
# Out:
# FamilySize
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %%
df_train.drop(['SibSp','Parch'],axis=1,inplace=True)
df_test.drop(['SibSp','Parch'],axis=1,inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Has_Duplicate_Ticket  \
# 0         0       3    male  22.0   7.2500        S                 False
# 1         1       1  female  38.0  71.2833        C                 False
# 2         1       3  female  26.0   7.9250        S                 False
# 3         1       1  female  35.0  53.1000        S                  True
# 4         0       3    male  35.0   8.0500        S                 False
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
df_train['Pclass'].replace({1:'Upper',2:'Middle',3:'Lower'},inplace=True)
df_test['Pclass'].replace({1:'Upper',2:'Middle',3:'Lower'},inplace=True)

# %%
df_train.head()
# Out:
#    Survived Pclass     Sex   Age     Fare Embarked  Has_Duplicate_Ticket  \
# 0         0  Lower    male  22.0   7.2500        S                 False
# 1         1  Upper  female  38.0  71.2833        C                 False
# 2         1  Lower  female  26.0   7.9250        S                 False
# 3         1  Upper  female  35.0  53.1000        S                  True
# 4         0  Lower    male  35.0   8.0500        S                 False
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
# Group and plot
family_survival = df_train.groupby("FamilySize")["Survived"].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=family_survival, x="FamilySize", y="Survived", palette="Blues_d")
plt.title("Survival Rate by Family Size")
plt.ylabel("Survival Rate")
plt.xlabel("Family Size")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
def family_size_bin(size):
    if size == 1:
        return "Alone"
    elif 2 <= size <= 3:
        return "Small"
    elif 4 <= size <= 5:
        return "Medium"
    else:
        return "Large"

# %%
df_train["FamilyGroup"] = df_train["FamilySize"].apply(family_size_bin)
df_test["FamilyGroup"] = df_test["FamilySize"].apply(family_size_bin)

# %%
df_train.head()
# Out:
#    Survived Pclass     Sex   Age     Fare Embarked  Has_Duplicate_Ticket  \
# 0         0  Lower    male  22.0   7.2500        S                 False
# 1         1  Upper  female  38.0  71.2833        C                 False
# 2         1  Lower  female  26.0   7.9250        S                 False
# 3         1  Upper  female  35.0  53.1000        S                  True
# 4         0  Lower    male  35.0   8.0500        S                 False
#
#    FamilySize FamilyGroup
# 0           2       Small
# 1           2       Small
# 2           1       Alone
# 3           2       Small
# 4           1       Alone

# %%
df_train.groupby(by=['FamilyGroup'])['Survived'].mean().sort_values(ascending=False)
# Out:
# FamilyGroup
# Small     0.562738
# Medium    0.545455
# Alone     0.303538
# Large     0.148936
# Name: Survived, dtype: float64

# %%
df_train.groupby(by=['FamilyGroup', 'Sex'])['Survived'].mean()
# Out:
# FamilyGroup  Sex
# Alone        female    0.785714
#              male      0.155718
# Large        female    0.285714
#              male      0.038462
# Medium       female    0.612903
#              male      0.384615
# Small        female    0.801471
#              male      0.307087
# Name: Survived, dtype: float64

# %%
df_train.drop(['FamilySize'],axis=1,inplace=True)
df_test.drop(['FamilySize'],axis=1,inplace=True)

# %%
df_train["GroupSurvivalRisk"] = df_train["Sex"] + "_" + df_train["FamilyGroup"]
df_test["GroupSurvivalRisk"] = df_test["Sex"] + "_" + df_test["FamilyGroup"]

# %%
df_train.groupby(by=['GroupSurvivalRisk'])['Survived'].mean().sort_values(ascending=False)
# Out:
# GroupSurvivalRisk
# female_Small     0.801471
# female_Alone     0.785714
# female_Medium    0.612903
# male_Medium      0.384615
# male_Small       0.307087
# female_Large     0.285714
# male_Alone       0.155718
# male_Large       0.038462
# Name: Survived, dtype: float64

# %%
df_train.head()
# Out:
#    Survived Pclass     Sex   Age     Fare Embarked  Has_Duplicate_Ticket  \
# 0         0  Lower    male  22.0   7.2500        S                 False
# 1         1  Upper  female  38.0  71.2833        C                 False
# 2         1  Lower  female  26.0   7.9250        S                 False
# 3         1  Upper  female  35.0  53.1000        S                  True
# 4         0  Lower    male  35.0   8.0500        S                 False
#
#   FamilyGroup GroupSurvivalRisk
# 0       Small        male_Small
# 1       Small      female_Small
# 2       Alone      female_Alone
# 3       Small      female_Small
# 4       Alone        male_Alone

# %%
df_train.drop(['Sex','FamilyGroup'],axis=1,inplace=True)
df_test.drop(['Sex','FamilyGroup'],axis=1,inplace=True)

# %%
df_submit = df_test[['PassengerId']]
df_test.drop(['PassengerId'],axis=1,inplace=True)

# %%
# Now Lets Do Preprocessing

# %%
X = df_train.drop('Survived', axis=1)
y = df_train['Survived']

# %%
numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns
cat_cols = X.select_dtypes(include=['object']).columns

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import  SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
preprocessing = ColumnTransformer(transformers=[
    ('num', Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]), numeric_cols),

    ('cat', Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(drop='first'))
    ]), cat_cols)
], remainder='passthrough')

# %%
import pickle

pickle.dump(preprocessing, open('preprocessing.pkl', 'wb'))

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train.drop('Survived', axis=1), df_train['Survived'], test_size=0.2, random_state=42)

# %%
X_valid = df_test

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'Support Vector Machine': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier()
}

# %%
params = {
    'Logistic Regression': {
        'C': [0.001, 0.01, 0.1, 1, 10, 100],
        'penalty': ['elasticnet', None],
        'class_weight': ['balanced', None]
    },
    'Decision Tree': {
        'max_depth': [None, 10, 20, 30, 40, 50],
        'criterion': ["gini", "entropy"],
        'min_samples_split': [2, 4, 6, 10, None]
    },
    'Random Forest': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20, 30, 40, 50],
        'criterion': ["gini", "entropy", "log_loss"]
    },
    'Gradient Boosting': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 0.2]
    },
    'Support Vector Machine': {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf']
    },
    'K-Nearest Neighbors': {
        'n_neighbors': [3, 5, 7, 9, 10]
    }
}

# %%
X_train_transformed = preprocessing.fit_transform(X_train)
X_test_transformed = preprocessing.transform(X_test)

# %%
import os
import pickle
from datetime import datetime

# %%
os.makedirs('preprocessor', exist_ok=True)
pickle.dump(preprocessing, open('preprocessor/preprocessor.pkl', 'wb'))

# %%
def evaluate_score(model, model_name, X_test, y_test):
    print(f"Calculating Score For {model_name}...")
    y_pred = model.predict(X_test)

    # Metrics
    acc = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    matrix = confusion_matrix(y_test, y_pred)

    # Print to console
    print(f"Accuracy Score: {acc}")
    print(f"Classification Report:\n{report}")
    print(f"Confusion Matrix:\n{matrix}")

    # Save model
    os.makedirs('models', exist_ok=True)
    with open(f'models/{model_name}.pkl', 'wb') as f:
        pickle.dump(model, f)

    # Append to single report file
    os.makedirs('reports', exist_ok=True)
    report_path = 'reports/model_evaluation_log.txt'
    with open(report_path, 'a') as f:
        f.write(f"\n{'='*60}\n")
        f.write(f"Model: {model_name}\n")
        f.write(f"Timestamp: {datetime.now()}\n")
        f.write(f"Accuracy Score: {acc:.4f}\n")
        f.write(f"R2 Score: {r2:.4f}\n")
        f.write("Classification Report:\n")
        f.write(report + "\n")
        f.write("Confusion Matrix:\n")
        f.write(str(matrix) + "\n")

    print(f"Appended report to: {report_path}")

# %%
def train_models(models, params, X_train, y_train, X_test, y_test):
  for model_name, model in models.items():
    print(f"Evaluating {model_name}...")
    grid_search = GridSearchCV(estimator=model, param_grid=params[model_name], cv=5)
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    print(f"Best Parameters: {grid_search.best_params_}")
    evaluate_score(best_model, model_name, X_test, y_test)

# %%
train_models(models, params, X_train_transformed, y_train, X_test_transformed, y_test)
# Out:
# Evaluating Logistic Regression...
# Best Parameters: {'C': 0.001, 'class_weight': None, 'penalty': None}
# Calculating Score For Logistic Regression...
# Accuracy Score: 0.8044692737430168
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       105
#            1       0.79      0.72      0.75        74
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.79      0.80       179
# weighted avg       0.80      0.80      0.80       179
#
# Confusion Matrix:
# [[91 14]
#  [21 53]]
# R2 Score: 0.1936936936936937
# Appended report to: reports/model_evaluation_log.txt
# Evaluating Decision Tree...
# Best Parameters: {'criterion': 'entropy', 'max_depth': 30, 'min_samples_split': 10}
# Calculating Score For Decision Tree...
# Accuracy Score: 0.8379888268156425
# Classification Report:
#               precision    recall  f1-score   support
#
# ...

# %%
from sklearn.ensemble import  StackingClassifier

# %%
# Define base learners
base_learners = [
    ('dt', DecisionTreeClassifier(criterion= 'entropy', max_depth= 30, min_samples_split = 10)),
    ('rf', RandomForestClassifier(n_estimators=200, criterion= 'log_loss', max_depth= 10)),
    ('gbc', GradientBoostingClassifier(learning_rate= 0.1, n_estimators= 100))
]
stacked_model = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression())

stacked_model.fit(X_train_transformed, y_train)
# Out:
# StackingClassifier(estimators=[('dt',
#                                 DecisionTreeClassifier(criterion='entropy',
#                                                        max_depth=30,
#                                                        min_samples_split=10)),
#                                ('rf',
#                                 RandomForestClassifier(criterion='log_loss',
#                                                        max_depth=10,
#                                                        n_estimators=200)),
#                                ('gbc', GradientBoostingClassifier())],
#                    final_estimator=LogisticRegression())

# %%
evaluate_score(stacked_model, 'stacked_model', X_test_transformed, y_test)
# Out:
# Calculating Score For stacked_model...
# Accuracy Score: 0.8268156424581006
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       105
#            1       0.83      0.73      0.78        74
#
#     accuracy                           0.83       179
#    macro avg       0.83      0.81      0.82       179
# weighted avg       0.83      0.83      0.82       179
#
# Confusion Matrix:
# [[94 11]
#  [20 54]]
# R2 Score: 0.28584298584298584
# Appended report to: reports/model_evaluation_log.txt

# %%
# Load preprocessor and model
preprocessor = pickle.load(open('preprocessor/preprocessor.pkl', 'rb'))
model = pickle.load(open('models/stacked_model.pkl', 'rb'))

# Transform validation data
X_valid_transformed = preprocessor.transform(X_valid)

# Predict and flatten to 1-D
y_pred = model.predict(X_valid_transformed)
y_pred = np.ravel(y_pred)          # or y_pred.flatten()

# Turn into a proper (n, 1) DataFrame
pred = pd.DataFrame({"Survived": y_pred})

# Make sure the lengths match
if len(pred) == len(df_submit):
    df_submit["Survived"] = pred["Survived"].values
else:
    raise ValueError(f"Length mismatch: pred has {len(pred)} rows, df_submit has {len(df_submit)} rows")

# Save to CSV
df_submit.to_csv("submission.csv", index=False)
print("✅ Submission saved as 'submission.csv'")
# Out:
# ✅ Submission saved as 'submission.csv'

# %%
df_submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
